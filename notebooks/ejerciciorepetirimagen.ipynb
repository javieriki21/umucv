# %%
import numpy             as np
import cv2               as cv
import matplotlib.pyplot as plt

# %%
img = cv.imread('../images/arrow2.jpg')

# %%
plt.imshow(img)
plt
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\JAVIER~1\\AppData\\Local\\R-MINI~1\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
img1 = img[1500:2500,2500:4000,[2,1,0]]
plt.imshow(img1);

# %%
img2 = np.hstack([img1,img1,img1,img1])
plt.imshow(img2)

# %%
img3 = np.vstack([img2,img2,img2])
plt.imshow(img3)
